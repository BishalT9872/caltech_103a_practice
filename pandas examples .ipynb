# %%
import pandas as pd
import numpy as np
import os

# %%
data_path="/Users/bishalthapa/Bishal Thapa/MIT/IAP/caltech BE/caltech_103a_practice"

# %%
fname = os.path.join(data_path, "gfmt_sleep.csv")
data=pd.read_csv(fname,na_values="*")

# %%
data.head(10)
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
# 5                  28      f   61                      80
# 6                  30      m   32                      90
# 7                  33      m   62                      45
# 8                  34      f   33                      80
# 9                  35      f   53                     100
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# ...

# %%
#dataframe are indexed with column so [column name][data name gives exact number]
data["gender"].count()
data["age"].mean()
# Out:
# 37.92156862745098

# %%
row=4
column="age"
data.loc[row,column]
# Out:
# 74

# %%
data.loc[(data["age"]<21)&(data["gender"]=="f"),:]
# Out:
#     participant number gender  age  correct hit percentage  \
# 27                   3      f   16                      70
# 29                   5      f   18                      90
# 66                  58      f   16                      85
# 79                  72      f   18                      80
# 88                  85      f   18                      85
#
#     correct reject percentage  percent correct  confidence when correct hit  \
# 27                         80             75.0                         70.0
# 29                        100             95.0                         76.5
# 66                         85             85.0                         55.0
# 79                         75             77.5                         67.5
# 88                         85             85.0                         93.0
#
#     confidence incorrect hit  confidence correct reject  \
# 27                      57.0                       54.0
# ...

# %%
data.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x7fdb2b55ec80>

# %%
data["insomania"]=data["sci"]<=16

# %%
data
# Out:
#      participant number gender  age  correct hit percentage  \
# 0                     8      f   39                      65
# 1                    16      m   42                      90
# 2                    18      f   31                      90
# 3                    22      f   35                     100
# 4                    27      f   74                      60
# ..                  ...    ...  ...                     ...
# 97                   97      f   23                      70
# 98                   98      f   70                      90
# 99                   99      f   24                      70
# 100                 102      f   40                      75
# 101                 103      f   33                      85
#
#      correct reject percentage  percent correct  confidence when correct hit  \
# 0                           80             72.5                         91.0
# 1                           90             90.0                         75.5
# ...

# %%
np.mean(data.loc[~data["insomania"],"percent correct"])
# Out:
# 81.46103896103897

# %%
data.describe().loc["50%",:]
# Out:
# participant number             52.50
# age                            36.50
# correct hit percentage         90.00
# correct reject percentage      80.00
# percent correct                83.75
# confidence when correct hit    75.00
# confidence incorrect hit       56.25
# confidence correct reject      71.25
# confidence incorrect reject    61.00
# confidence when correct        75.75
# confidence when incorrect      61.50
# sci                            23.50
# psqi                            5.00
# ess                             7.00
# Name: 50%, dtype: float64

# %%
data.to_csv("gfmt_with_insomania.csv",index=False)

# %%
# !ls
# Out:
# GC_TEST.py                            neg_AA.py
# LICENSE                               packages and modeules.ipynb
# Methods_review.ipynb                  pandas examples .ipynb
# README.md                             seq_features.py
# Untitled.ipynb                        simpleplot.py
# __pycache__                           test driven deployment.ipynb
# function.ipynb                        test1.ipynb
# gfmt_sleep.csv                        test2.html
# gfmt_with_insomania.csv               test2.ipynb
# images_medium_ja-2017-13292m_0002.gif test_aminoacid.py
# list_comprehension.ipynb              zen.py

# %%
# !git add -A

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   .ipynb_checkpoints/pandas examples -checkpoint.ipynb
# 	new file:   gfmt_with_insomania.csv
# 	new file:   pandas examples .ipynb

# %%
# !git commit -m "using pandas dataframe "
# Out:
# [main f205e50] using pandas dataframe
#  3 files changed, 1135 insertions(+)
#  create mode 100644 .ipynb_checkpoints/pandas examples -checkpoint.ipynb
#  create mode 100644 gfmt_with_insomania.csv
#  create mode 100644 pandas examples .ipynb

# %%
# !git push
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 10 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 6.39 KiB | 6.39 MiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/BishalT9872/caltech_103a_practice.git
#    837bafb..f205e50  main -> main

# %%
# !git pull
# Out:
# Already up to date.

# %%
data.iloc[:,1]
# Out:
# 0      f
# 1      m
# 2      f
# 3      f
# 4      f
#       ..
# 97     f
# 98     f
# 99     f
# 100    f
# 101    f
# Name: gender, Length: 102, dtype: object

# %%
df=data
# Make a dictionary to rename columns
rename_dict = {
    "ess": "Epworth Sleepiness Scale",
    "sci": "Sleep Condition Indicator",
    "psqi": "Pittsburgh Sleep Quality Index",
}

# Rename the columns
df = df.rename(columns=rename_dict)

df.head()
# Out:
#    participant number gender  age  correct hit percentage  \
# 0                   8      f   39                      65
# 1                  16      m   42                      90
# 2                  18      f   31                      90
# 3                  22      f   35                     100
# 4                  27      f   74                      60
#
#    correct reject percentage  percent correct  confidence when correct hit  \
# 0                         80             72.5                         91.0
# 1                         90             90.0                         75.5
# 2                         95             92.5                         89.5
# 3                         75             87.5                         89.5
# 4                         65             62.5                         68.5
#
#    confidence incorrect hit  confidence correct reject  \
# 0                      90.0                       93.0
# ...
